# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
for file in files:
    y,sr = librosa.load(file)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    S_delta = librosa.feature.delta(S)
    S_delta2 = librosa.feature.delta(S, order=2)
    print y.shape
    print sr
    print S.shape
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(S,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(S_delta,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('delta')
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(S_delta2,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('delta2')
    #plt.tight_layout()
# Out:
# (42900,)
# 22050
# (128, 84)
# (30483,)
# 22050
# (128, 60)

# %%
arr = np.arange(7719)
np.random.seed(5)
np.random.shuffle(arr)
arr
# Out:
# array([2157, 6471, 2637, ..., 4079, 2254, 2915])

# %%
len(arr)
# Out:
# 7719

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
for file in files:
    y,sr = librosa.load(file)
    S = np.zeros((128,100))
    print S.shape
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 256, fmax =8000)
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    #print mfsc
    print mfsc.shape
    S[:,0:mfsc.shape[1]] = mfsc
    S_delta = librosa.feature.delta(S)
    S_delta2 = librosa.feature.delta(S, order=2)
    print S_delta.shape
    print S_delta2.shape
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(S,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(S_delta,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(S_delta2,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    print "\n"
# Out:
# (128, 100)
# (128, 84)
# (128, 100)
# (128, 100)
#
#
# (128, 100)
# (128, 60)
# (128, 100)
# (128, 100)

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
#files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
files = open("../filename.txt",'r')
i =0
size = []
for file in files:
    file =file.strip("\n")+".wav"
    y,sr = librosa.load(os.path.join("../Complete", file))
    
    size.append(librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000).shape[1])
    print size[i]
    i = i+1
print size
# Out:
# 84
# 60
# 135
# 174
# 200
# 242
# 115
# 177
# 126
# 423
# 119
# 145
# 219
# 119
# 126
# 161
# 125
# 197
# 122
# 350
# 248
# 269
# 190
# 323
# 192
# 260
# 402
# 127
# 247
# 244
# 249
# 111
# 182
# 267
# 184
# 131
# 264
# 319
# 155
# 95
# 287
# 132
# 132
# 196
# 131
# 269
# 274
# 143
# 300
# 165
# 114
# 159
# 182
# 139
# 202
# 204
# 199
# 54
# 191
# 124
# 149
# 111
# 199
# 163
# 112
# 274
# 193
# 115
# 74
# 99
# 221
# 248
# 198
# 89
# 129
# 126
# 62
# 236
# 98
# 37
# 190
# 170
# 259
# 96
# 89
# 172
# 91
# 119
# 57
# 212
# 170
# 121
# 94
# 78
# 115
# 62
# 207
# 199
# 116
# 72
# 159
# 96
# 190
# 190
# 530
# 104
# 154
# 181
# 60
# 183
# 65
# 157
# 114
# 246
# 319
# 160
# 76
# 186
# 91
# 110
# 117
# 137
# 87
# 137
# 138
# 190
# 125
# 252
# 169
# 72
# 141
# 78
# 200
# 144
# 131
# 52
# 49
# 116
# 76
# 164
# 102
# 147
# 331
# 298
# 129
# 122
# 262
# 57
# 83
# 420
# 100
# 198
# 95
# 138
# 104
# 115
# 54
# 189
# 152
# 124
# 118
# 117
# 166
# 43
# 82
# 65
# 165
# 418
# 61
# 57
# 92
# 316
# 182
# ...

# %%
print np.mean(size)
# Out:
# 198.49358725223473

# %%
print np.percentile(size, 50)
print np.percentile(size, 75)
# Out:
# 158.0
# 255.5

# %%
print np.max(size)
# Out:
# 1471

# %%
print np.min(size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b89c0d670ab8> in <module>()
# ----> 1 print np.min(size)
#
# NameError: name 'np' is not defined

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pickle as pkl
files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
for file in files:
    y,sr = librosa.load(file)
    S = np.zeros((128,256))
    print S.shape
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    print mfsc.shape
    S[:,0:mfsc.shape[1]] = mfsc
    S_delta = librosa.feature.delta(S)
    S_delta2 = librosa.feature.delta(S, order=2)
    print y.shape
    print sr
    print S.shape[1]
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(S,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
# Out:
# (128, 256)
# (128, 84)
# (42900,)
# 22050
# 256
# (128, 256)
# (128, 60)
# (30483,)
# 22050
# 256

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pickle as pkl
mfsc_file = open("mfsc.pkl","wb")
label_dict= {'Neutral': 0, 'Happiness': 1, 'Sadness':2 ,'Anger': 3}
print label_dict['Happiness']

files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
for file in files:
    y,sr = librosa.load(file)
    S = np.zeros((128,256))
    print S.shape
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    print mfsc.shape
    S[:,0:mfsc.shape[1]] = mfsc
    S_delta = librosa.feature.delta(S)
    S_delta2 = librosa.feature.delta(S, order=2)
    print y.shape
    print sr
    print S.shape[1]
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(S,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    
    pkl.dump([S, ,mfsc_file)
# Out:
# 1
# "\nfiles = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]\nfor file in files:\n    y,sr = librosa.load(file)\n    S = np.zeros((128,256))\n    print S.shape\n    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)\n    print mfsc.shape\n    S[:,0:mfsc.shape[1]] = mfsc\n    S_delta = librosa.feature.delta(S)\n    S_delta2 = librosa.feature.delta(S, order=2)\n    print y.shape\n    print sr\n    print S.shape[1]\n    plt.figure(figsize=(10, 4))\n    librosa.display.specshow(librosa.power_to_db(S,ref=np.max),y_axis='mel', fmax=8000,x_axis='time')\n    plt.colorbar(format='%+2.0f dB')\n    plt.title('Mel spectrogram')\n    \n    pkl.dump(S,mfsc_file)\n"

# %%
label_dict= {'Neutral': 0, 'Happiness': 1, 'Sadness':2 ,'Anger': 3}
print label_dict['Happiness']
# Out:
# 1

# %%
ls
# Out:
# convert_mfsc.py  mfsc.py   Ses01F_impro01_F000.wav
# mfsc.pkl         p1.ipynb  Ses01F_impro01_F001.wav

# %%
ls
# Out:
# convert_mfsc.py  mfsc.py     p1.ipynb                 Ses01F_impro01_F001.wav
# mfsc.pkl         output.txt  Ses01F_impro01_F000.wav

# %%
import os
Allfiles = open("output.txt",'r')
files_taken_for_training = open("files_taken_for_training.txt",'w')
supported_label = ['Neutral', 'Happiness', 'Sadness' ,'Anger']
for line in Allfiles:
    filename = line.split()
    if "impro" in filename[0] and filename[1] in supported_label:
        files_taken_for_training.write(filename[0]+"\n")
Allfiles.close()
files_taken_for_training.close()

# %%
wc -l files_taken_for_training.txt
# Out:
#   File "<ipython-input-23-aad385dd7578>", line 1
#     wc -l files_taken_for_training.txt
#                                  ^
# SyntaxError: invalid syntax

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pickle as pkl
#files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
supported_label = ['Neutral', 'Happiness', 'Sadness' ,'Anger']
label_dict= {'Neutral': 0, 'Happiness': 1, 'Sadness':2 ,'Anger': 3}

########### files ########################
Allfiles = open("output1.txt",'r')
files_taken_for_training = open("files_taken_for_training.txt",'w')
mfsc_file = open("mfsc1.pkl","wb")


################## selecting files needed for training : 4 supported class and improvised wav files ##############
for line in Allfiles:
    filename = line.split()
    if "impro" in filename[0] and filename[1] in supported_label:
        files_taken_for_training.write(filename[0]+"\t"+filename[1]+ "\n")
Allfiles.close()
files_taken_for_training.close()
   
files = open("files_taken_for_training.txt",'r')

#################### creating mfsc for each file and dump to mfsc.pkl ################################

arr1 = []
arr2 = []
for file in files:
    print file.split("\t")
    
    ############# sampling rate, sr = 22050 ###########################
    y,sr = librosa.load(os.path.join("../Complete", file.split("\t")[0]+".wav"))
    S = np.zeros((128,256))
    
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    print mfsc.shape
    if mfsc.shape[1] < S.shape[1]:
        S[:,0:mfsc.shape[1]] = mfsc
    else:
        S[:,0:mfsc.shape[1]] = mfsc[:,0:256]
    #S_delta = librosa.feature.delta(S)
    #S_delta2 = librosa.feature.delta(S, order=2)
    #print y.shape
    #print S
    S_db = librosa.power_to_db(S,ref=np.max)
    
   
    
    '''
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    '''
    #print S_db.shape

    print label_dict[file.split("\t")[1].strip("\n")]
    #pkl.dump([S_db, label_dict[file.split("\t")[1].strip("\n")]],mfsc_file)
    arr1.append(S_db)  
    arr2.append(label_dict[file.split("\t")[1].strip("\n")])  
arr = [arr1, arr2]
pkl.dump(arr, mfsc_file)

files.close()
mfsc_file.close()



'''

size = []
i=0
for file in files:
    file =file.strip("\n")+".wav"
    y,sr = librosa.load(os.path.join("../Complete", file))
    
    size.append(librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000).shape[1])
    i=i+1
print size
'''
# Out:
# ['Ses01F_impro01_F000', 'Neutral\n']
# (128, 84)
# 0
# ['Ses01F_impro01_F001', 'Neutral\n']
# (128, 60)
# 0
# ['Ses01F_impro01_F002', 'Neutral\n']
# (128, 135)
# 0
# ['Ses01F_impro01_F005', 'Neutral\n']
# (128, 174)
# 0
# '\n\nsize = []\ni=0\nfor file in files:\n    file =file.strip("\n")+".wav"\n    y,sr = librosa.load(os.path.join("../Complete", file))\n    \n    size.append(librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000).shape[1])\n    i=i+1\nprint size\n'

# %%
arr = np.arange(2250)
np.random.seed(5)
np.random.shuffle(arr)
arr
# Out:
# array([ 621,  432,  133, ..., 2121, 1424, 1725])

# %%
print np.max(arr)
print np.min(arr)
# Out:
# 2249
# 0

# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4a69013be9f0> in <module>()
# ----> 1 python
#
# NameError: name 'python' is not defined

# %%
arr1 = np.arange(50)
np.random.seed(5)
np.random.shuffle(arr1)
np.split(arr1,2)
# Out:
# [array([42, 29,  6, 19, 28, 17,  2, 43,  3, 21, 31,  4, 32,  0, 23,  5, 48,
#         34, 37, 26, 41, 33, 24, 10, 44]),
#  array([25, 18, 22, 20, 49,  1, 11, 13, 40, 46, 15, 12,  7, 45, 30, 27, 39,
#         36,  8,  9, 16, 38, 47, 14, 35])]

# %%
arr1 = np.arange(50)
np.random.seed(5)
np.random.shuffle(arr1)
np.split(arr1,[8,2])
# Out:
# [array([42, 29,  6, 19, 28, 17,  2, 43]),
#  array([], dtype=int64),
#  array([ 6, 19, 28, 17,  2, 43,  3, 21, 31,  4, 32,  0, 23,  5, 48, 34, 37,
#         26, 41, 33, 24, 10, 44, 25, 18, 22, 20, 49,  1, 11, 13, 40, 46, 15,
#         12,  7, 45, 30, 27, 39, 36,  8,  9, 16, 38, 47, 14, 35])]

# %%
ind = np.arange(2250)
np.random.seed(5)
np.random.shuffle(ind)
a1,a2 = np.split(ind,[450])
print a1
print a2
# Out:
# [ 621  432  133  220  606  477   72  419  293 1601 1789   54 1114 1420
#   859  796 1674  924 2086  356 2146  469 1627  896 2024  973  626  704
#   995  871  544 1397 2229 2206  780 2244  894  795  600 1157  178 1098
#  1882 1772 1444  177 1704 1340  734 1259 1783  527  433  482 2016 1523
#  2044  416  840   33 1116 1618 1773 1236 1602 1635   86  126  346 1711
#   599  444 1046  338 1753 1648 1761 1887  194  295 1792 1402  559 1758
#  1251 1329 1150  395 1647 2117 1962 1200 1291  909 1264 1005 2221 1087
#  1153   65 1821  139 1865  475 1793 1536 2035 1227  586 1342 1769  132
#  1367 1481  720  503 1487 1231 1630  285  757  797 1121  729 2187  348
#  2235  300 1662 1191  246 1534 2236  823  156 2151 1794  217  856 1152
#   988 1595 1708  620 1899 1557  915  836  509   71 1051  958 1655  862
#  1305 1432 1867  603  124 1484  176 2185  146  120 1954 2138 2027  424
#  1466 2175   47 1190 1076 2153  772  737 1875   35 1524  954  447  938
# ...

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pickle as pkl
#files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
supported_label = ['Neutral', 'Happiness', 'Sadness' ,'Anger']
label_dict= {'Neutral': 0, 'Happiness': 1, 'Sadness':2 ,'Anger': 3}

########### files ########################
Allfiles = open("output.txt",'r')
files_taken_for_training = open("files_taken_for_training.txt",'w')
train_mfsc_file = open("train_mfsc1.pkl","wb")
test_mfsc_file = open("test_mfsc1.pkl","wb")

######################Spliting test and train data #####################
ind = np.arange(2250)
np.random.seed(5)
np.random.shuffle(ind)
ind1,ind2 = np.split(ind,[450])


################## selecting files needed for training : 4 supported class and improvised wav files ##############
for line in Allfiles:
    filename = line.split()
    if "impro" in filename[0] and filename[1] in supported_label:
        files_taken_for_training.write(filename[0]+"\t"+filename[1]+ "\n")
Allfiles.close()
files_taken_for_training.close()
   
files = open("files_taken_for_training.txt",'r')

#################### creating mfsc for each file and dump to mfsc.pkl ################################

train_arr1 = []
train_arr2 = []
test_arr1 = []
test_arr2 = []
linecount = 0
for file in files:
    print file.split("\t")
    
    ############# sampling rate, sr = 22050 ###########################
    y,sr = librosa.load(os.path.join("../Complete", file.split("\t")[0]+".wav"))
    S = np.zeros((128,256))
    
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    print mfsc.shape
    if mfsc.shape[1] < S.shape[1]:
        S[:,0:mfsc.shape[1]] = mfsc
    else:
        S[:,0:mfsc.shape[1]] = mfsc[:,0:256]
    #S_delta = librosa.feature.delta(S)
    #S_delta2 = librosa.feature.delta(S, order=2)
    #print y.shape
    #print S
    S_db = librosa.power_to_db(S,ref=np.max)
    
   
    
    '''
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    '''
    #print S_db.shape

    print label_dict[file.split("\t")[1].strip("\n")]
    
    if linecount in ind2:
        train_arr1.append(S_db)  
        train_arr2.append(label_dict[file.split("\t")[1].strip("\n")])  
    else:
        test_arr1.append(S_db) 
        test_arr2.append(label_dict[file.split("\t")[1].strip("\n")])
        
    linecount = linecount + 1
train_arr = [train_arr1, train_arr2]
test_arr = [test_arr1, test_arr2]

pkl.dump(train_arr, train_mfsc_file)
pkl.dump(test_arr, test_mfsc_file)

files.close()
train_mfsc_file.close()
test_mfsc_file.close()


'''

size = []
i=0
for file in files:
    file =file.strip("\n")+".wav"
    y,sr = librosa.load(os.path.join("../Complete", file))
    
    size.append(librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000).shape[1])
    i=i+1
print size
'''
# Out:
# ['Ses01F_impro01_F000', 'Neutral\n']
# (128, 84)
# 0
# ['Ses01F_impro01_F001', 'Neutral\n']
# (128, 60)
# 0
# ['Ses01F_impro01_F002', 'Neutral\n']
# (128, 135)
# 0
# ['Ses01F_impro01_F005', 'Neutral\n']
# (128, 174)
# 0
# ['Ses01F_impro01_F012', 'Anger\n']
# (128, 119)
# 3
# ['Ses01F_impro01_F014', 'Neutral\n']
# (128, 219)
# 0
# ['Ses01F_impro01_M013', 'Anger\n']
# (128, 260)
# 3
# ['Ses01F_impro02_F000', 'Sadness\n']
# (128, 402)
# 2
# ['Ses01F_impro02_F001', 'Sadness\n']
# (128, 127)
# 2
# ['Ses01F_impro02_F002', 'Sadness\n']
# (128, 247)
# 2
# ['Ses01F_impro02_F003', 'Neutral\n']
# (128, 244)
# 0
# ['Ses01F_impro02_F004', 'Sadness\n']
# (128, 249)
# 2
# ['Ses01F_impro02_F005', 'Sadness\n']
# (128, 111)
# 2
# ['Ses01F_impro02_F006', 'Neutral\n']
# (128, 182)
# 0
# ['Ses01F_impro02_F010', 'Sadness\n']
# (128, 184)
# 2
# ['Ses01F_impro02_F012', 'Sadness\n']
# (128, 131)
# 2
# ['Ses01F_impro02_F013', 'Sadness\n']
# (128, 264)
# 2
# ['Ses01F_impro02_F014', 'Sadness\n']
# (128, 319)
# ...

# %%
########################SAMPLE CODE ####################################
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import matplotlib
import pickle as pkl
#files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
supported_label = ['Neutral', 'Happiness', 'Sadness' ,'Anger']
label_dict= {'Neutral': 0, 'Happiness': 1, 'Sadness':2 ,'Anger': 3}

########### files ########################
Allfiles = open("output1.txt",'r')
files_taken_for_training = open("files_taken_for_training.txt",'w')
train_mfsc_file = open("train_mfsc2.pkl","wb")
test_mfsc_file = open("test_mfsc2.pkl","wb")

######################Spliting test and train data #####################
ind = np.arange(25)
np.random.seed(5)
np.random.shuffle(ind)
ind1,ind2 = np.split(ind,[5])


################## selecting files needed for training : 4 supported class and improvised wav files ##############
for line in Allfiles:
    filename = line.split()
    if "impro" in filename[0] and filename[1] in supported_label:
        files_taken_for_training.write(filename[0]+"\t"+filename[1]+ "\n")
Allfiles.close()
files_taken_for_training.close()
   
files = open("files_taken_for_training.txt",'r')

#################### creating mfsc for each file and dump to mfsc.pkl ################################

train_arr1 = []
train_arr2 = []
test_arr1 = []
test_arr2 = []
linecount = 0
for file in files:
    print file.split("\t")
    
    ############# sampling rate, sr = 22050 ###########################
    y,sr = librosa.load(os.path.join("../Complete", file.split("\t")[0]+".wav"))
    S = np.zeros((128,256))
    
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    print mfsc.shape
    if mfsc.shape[1] < S.shape[1]:
        S[:,0:mfsc.shape[1]] = mfsc
    else:
        S[:,0:mfsc.shape[1]] = mfsc[:,0:256]
    #S_delta = librosa.feature.delta(S)
    #S_delta2 = librosa.feature.delta(S, order=2)
    #print y.shape
    #print S
    S_db = librosa.power_to_db(S,ref=np.max)
    
   
    matplotlib.image.imsave("fig2"+str(linecount)+'.png',librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time'))
    fig_name= "fig"+str(linecount)
    fig_name= plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time')
    #plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    #fig_name.savefig("fig"+str(linecount)+'.png')
    #print S_db.shape

    print label_dict[file.split("\t")[1].strip("\n")]
    
    if linecount in ind2:
        train_arr1.append(S_db)  
        train_arr2.append(label_dict[file.split("\t")[1].strip("\n")])  
    else:
        test_arr1.append(S_db) 
        test_arr2.append(label_dict[file.split("\t")[1].strip("\n")])
        
    linecount = linecount + 1
train_arr = [train_arr1, train_arr2]
test_arr = [test_arr1, test_arr2]

pkl.dump(train_arr, train_mfsc_file)
pkl.dump(test_arr, test_mfsc_file)

files.close()
train_mfsc_file.close()
test_mfsc_file.close()


'''

size = []
i=0
for file in files:
    file =file.strip("\n")+".wav"
    y,sr = librosa.load(os.path.join("../Complete", file))
    
    size.append(librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000).shape[1])
    i=i+1
print size
'''
# Out:
# ['Ses01F_impro01_F000', 'Neutral\n']
# (128, 84)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-3ad21fc1271c> in <module>()
#      61
#      62
# ---> 63     matplotlib.image.imsave("fig2"+str(linecount)+'.png',librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time'))
#      64     fig_name= "fig"+str(linecount)
#      65     fig_name= plt.figure(figsize=(10, 4))
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi)
#    1422             and fname.lower().endswith('.png'))):
#    1423         image = AxesImage(None, cmap=cmap, origin=origin)
# -> 1424         image.set_data(arr)
#    1425         image.set_clim(vmin, vmax)
#    1426         image.write_png(fname)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/image.pyc in set_data(self, A)
# ...

# %%
######################### MFSC + delta + delta_delta ###################################
########################################################################################
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pickle as pkl
#files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
supported_label = ['Neutral', 'Happiness', 'Sadness' ,'Anger']
label_dict= {'Neutral': 0, 'Happiness': 1, 'Sadness':2 ,'Anger': 3}

########### files ########################
Allfiles = open("output1.txt",'r')
files_taken_for_training = open("files_taken_for_training.txt",'w')
train_mfsc_file = open("train_mfsc3.pkl","wb")
test_mfsc_file = open("test_mfsc3.pkl","wb")

######################Spliting test and train data #####################
ind = np.arange(25)
np.random.seed(5)
np.random.shuffle(ind)
ind1,ind2 = np.split(ind,[5])


################## selecting files needed for training : 4 supported class and improvised wav files ##############
for line in Allfiles:
    filename = line.split()
    if "impro" in filename[0] and filename[1] in supported_label:
        files_taken_for_training.write(filename[0]+"\t"+filename[1]+ "\n")
Allfiles.close()
files_taken_for_training.close()
   
files = open("files_taken_for_training.txt",'r')

#################### creating mfsc for each file and dump to mfsc.pkl ################################

train_arr1 = []
train_arr2 = []
train_arr3_d = []
train_arr4_dd = []
test_arr1 = []
test_arr2 = []
test_arr3_d = []
test_arr4_dd = []
linecount = 0
for file in files:
    print file.split("\t")
    
    ############# sampling rate, sr = 22050 ###########################
    y,sr = librosa.load(os.path.join("../Complete", file.split("\t")[0]+".wav"))
    S = np.zeros((128,256))
    
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    print mfsc.shape
    if mfsc.shape[1] < S.shape[1]:
        S[:,0:mfsc.shape[1]] = mfsc
    else:
        S[:,0:mfsc.shape[1]] = mfsc[:,0:256]
    #S_delta = librosa.feature.delta(S)
    #S_delta2 = librosa.feature.delta(S, order=2)
    #print y.shape
    #print S
    S_db = librosa.power_to_db(S,ref=np.max)
    S_delta = librosa.feature.delta(S_db)
    S_delta2 = librosa.feature.delta(S_db, order=2)
   
    
    '''
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    '''
    #print S_db.shape

    print label_dict[file.split("\t")[1].strip("\n")]
    
    if linecount in ind2:
        train_arr1.append(S_db)  
        train_arr2.append(label_dict[file.split("\t")[1].strip("\n")])  
        train_arr3_d.append(S_delta)
        train_arr4_dd.append(S_delta2)
    else:
        test_arr1.append(S_db) 
        test_arr2.append(label_dict[file.split("\t")[1].strip("\n")])
        test_arr3_d.append(S_delta)
        test_arr4_dd.append(S_delta2)
        
    linecount = linecount + 1
train_arr = [train_arr1, train_arr2, train_arr3_d, train_arr4_dd]
test_arr = [test_arr1, test_arr2, test_arr3_d, test_arr4_dd]

pkl.dump(train_arr, train_mfsc_file)
pkl.dump(test_arr, test_mfsc_file)

files.close()
train_mfsc_file.close()
test_mfsc_file.close()


'''

size = []
i=0
for file in files:
    file =file.strip("\n")+".wav"
    y,sr = librosa.load(os.path.join("../Complete", file))
    
    size.append(librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000).shape[1])
    i=i+1
print size
'''
# Out:
# ['Ses01F_impro01_F000', 'Neutral\n']
# (128, 84)
# 0
# ['Ses01F_impro01_F001', 'Neutral\n']
# (128, 60)
# 0
# ['Ses01F_impro01_F002', 'Neutral\n']
# (128, 135)
# 0
# ['Ses01F_impro01_F005', 'Neutral\n']
# (128, 174)
# 0
# ['Ses01F_impro01_F012', 'Anger\n']
# (128, 119)
# 3
# ['Ses01F_impro01_F014', 'Neutral\n']
# (128, 219)
# 0
# ['Ses01F_impro01_M013', 'Anger\n']
# (128, 260)
# 3
# ['Ses01F_impro02_F000', 'Sadness\n']
# (128, 402)
# 2
# ['Ses01F_impro02_F001', 'Sadness\n']
# (128, 127)
# 2
# ['Ses01F_impro02_F002', 'Sadness\n']
# (128, 247)
# 2
# ['Ses01F_impro02_F003', 'Neutral\n']
# (128, 244)
# 0
# ['Ses01F_impro02_F019', 'Sadness\n']
# (128, 132)
# 2
# ['Ses01F_impro02_F020', 'Sadness\n']
# (128, 196)
# 2
# ['Ses01F_impro02_M009', 'Sadness\n']
# (128, 159)
# 2
# ['Ses01F_impro02_M010', 'Sadness\n']
# (128, 182)
# 2
# ['Ses01F_impro02_M011', 'Sadness\n']
# (128, 139)
# 2
# ['Ses01F_impro02_M012', 'Neutral\n']
# (128, 202)
# 0
# ['Ses01F_impro02_M013', 'Sadness\n']
# (128, 204)
# ...

# %%
######################### MFSC + delta + delta_delta ###################################
########################################################################################
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pickle as pkl
#files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
supported_label = ['Neutral', 'Happiness', 'Sadness' ,'Anger']
label_dict= {'Neutral': 0, 'Happiness': 1, 'Sadness':2 ,'Anger': 3}

########### files ########################
Allfiles = open("output.txt",'r')
files_taken_for_training = open("files_taken_for_training.txt",'w')
train_mfsc_file = open("train_mfsc1.pkl","wb")
test_mfsc_file = open("test_mfsc1.pkl","wb")

######################Spliting test and train data #####################
ind = np.arange(2250)
np.random.seed(5)
np.random.shuffle(ind)
ind1,ind2 = np.split(ind,[450])


################## selecting files needed for training : 4 supported class and improvised wav files ##############
for line in Allfiles:
    filename = line.split()
    if "impro" in filename[0] and filename[1] in supported_label:
        files_taken_for_training.write(filename[0]+"\t"+filename[1]+ "\n")
Allfiles.close()
files_taken_for_training.close()
   
files = open("files_taken_for_training.txt",'r')

#################### creating mfsc for each file and dump to mfsc.pkl ################################

train_arr1 = []
train_arr2 = []
train_arr3_d = []
train_arr4_dd = []
test_arr1 = []
test_arr2 = []
test_arr3_d = []
test_arr4_dd = []
linecount = 0
for file in files:
    print file.split("\t")
    
    ############# sampling rate, sr = 22050 ###########################
    y,sr = librosa.load(os.path.join("../Complete", file.split("\t")[0]+".wav"))
    S = np.zeros((128,256))
    
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    print mfsc.shape
    if mfsc.shape[1] < S.shape[1]:
        S[:,0:mfsc.shape[1]] = mfsc
    else:
        S[:,0:mfsc.shape[1]] = mfsc[:,0:256]
    #S_delta = librosa.feature.delta(S)
    #S_delta2 = librosa.feature.delta(S, order=2)
    #print y.shape
    #print S
    S_db = librosa.power_to_db(S,ref=np.max)
    S_delta = librosa.feature.delta(S_db)
    S_delta2 = librosa.feature.delta(S_db, order=2)
   
    
    '''
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    '''
    #print S_db.shape

    print label_dict[file.split("\t")[1].strip("\n")]
    
    if linecount in ind2:
        train_arr1.append(S_db)  
        train_arr2.append(label_dict[file.split("\t")[1].strip("\n")])  
        train_arr3_d.append(S_delta)
        train_arr4_dd.append(S_delta2)
    else:
        test_arr1.append(S_db) 
        test_arr2.append(label_dict[file.split("\t")[1].strip("\n")])
        test_arr3_d.append(S_delta)
        test_arr4_dd.append(S_delta2)
        
    linecount = linecount + 1
train_arr = [train_arr1, train_arr2, train_arr3_d, train_arr4_dd]
test_arr = [test_arr1, test_arr2, test_arr3_d, test_arr4_dd]

pkl.dump(train_arr, train_mfsc_file)
pkl.dump(test_arr, test_mfsc_file)

files.close()
train_mfsc_file.close()
test_mfsc_file.close()


'''

size = []
i=0
for file in files:
    file =file.strip("\n")+".wav"
    y,sr = librosa.load(os.path.join("../Complete", file))
    
    size.append(librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000).shape[1])
    i=i+1
print size
'''
# Out:
# ['Ses01F_impro01_F000', 'Neutral\n']
# (128, 84)
# 0
# ['Ses01F_impro01_F001', 'Neutral\n']
# (128, 60)
# 0
# ['Ses01F_impro01_F002', 'Neutral\n']
# (128, 135)
# 0
# ['Ses01F_impro01_F005', 'Neutral\n']
# (128, 174)
# 0
# ['Ses01F_impro01_F012', 'Anger\n']
# (128, 119)
# 3
# ['Ses01F_impro01_F014', 'Neutral\n']
# (128, 219)
# 0
# ['Ses01F_impro01_M013', 'Anger\n']
# (128, 260)
# 3
# ['Ses01F_impro02_F000', 'Sadness\n']
# (128, 402)
# 2
# ['Ses01F_impro02_F001', 'Sadness\n']
# (128, 127)
# 2
# ['Ses01F_impro02_F002', 'Sadness\n']
# (128, 247)
# 2
# ['Ses01F_impro02_F003', 'Neutral\n']
# (128, 244)
# 0
# ['Ses01F_impro02_F004', 'Sadness\n']
# (128, 249)
# 2
# ['Ses01F_impro02_F005', 'Sadness\n']
# (128, 111)
# 2
# ['Ses01F_impro02_F006', 'Neutral\n']
# (128, 182)
# 0
# ['Ses01F_impro02_F010', 'Sadness\n']
# (128, 184)
# 2
# ['Ses01F_impro02_F012', 'Sadness\n']
# (128, 131)
# 2
# ['Ses01F_impro02_F013', 'Sadness\n']
# (128, 264)
# 2
# ['Ses01F_impro02_F014', 'Sadness\n']
# (128, 319)
# ...

# %%
ls
# Out:
# convert_mfsc.py               p1.ipynb                 test_mfsc2.pkl
# files_taken_for_training.txt  preprocess.py            test_mfsc3.pkl
# keras_cnn.ipynb               Ses01F_impro01_F000.wav  train_mfsc1.pkl
# mfsc.py                       Ses01F_impro01_F001.wav  train_mfsc2.pkl
# output1.txt                   temp.pkl                 train_mfsc3.pkl
# output.txt                    test_mfsc1.pkl

# %%
mkdir train

# %%
ls
# Out:
# convert_mfsc.py               p1.ipynb                 test_mfsc2.pkl
# files_taken_for_training.txt  preprocess.py            test_mfsc3.pkl
# keras_cnn.ipynb               Ses01F_impro01_F000.wav  train/
# mfsc.py                       Ses01F_impro01_F001.wav  train_mfsc1.pkl
# output1.txt                   temp.pkl                 train_mfsc2.pkl
# output.txt                    test_mfsc1.pkl           train_mfsc3.pkl

# %%
mkdir validation

# %%
import pickle as pk

# %%
f1=pk.load(open("train_mfsc1.pkl"))

# %%
print len(f1)
print f1[3][0].shape
# Out:
# 4
# (128, 256)

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pickle as pkl
import matplotlib


#files = [f for f in os.listdir('.') if f.endswith('.wav') and not f.startswith('.')]
supported_label = ['Neutral', 'Happiness', 'Sadness' ,'Anger']
label_dict= {'Neutral': 0, 'Happiness': 1, 'Sadness':2 ,'Anger': 3}

########### files ########################
Allfiles = open("output.txt",'r')
files_taken_for_training = open("files_taken_for_training.txt",'w')

######################Spliting test and train data #####################
ind = np.arange(2250)
np.random.seed(5)
np.random.shuffle(ind)
ind1,ind2 = np.split(ind,[450])


################## selecting files needed for training : 4 supported class and improvised wav files ##############
for line in Allfiles:
    filename = line.split()
    if "impro" in filename[0] and filename[1] in supported_label:
        files_taken_for_training.write(filename[0]+"\t"+filename[1]+ "\n")
Allfiles.close()
files_taken_for_training.close()
   
files = open("files_taken_for_training.txt",'r')

#################### creating mfsc for each file and dump to mfsc.pkl ################################

linecount = 0
for file in files:
    print file.split("\t")
    
    ############# sampling rate, sr = 22050 ###########################
    y,sr = librosa.load(os.path.join("../Complete", file.split("\t")[0]+".wav"))
    S = np.zeros((128,256))
    
    mfsc = librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000)
    print mfsc.shape
    if mfsc.shape[1] < S.shape[1]:
        S[:,0:mfsc.shape[1]] = mfsc
    else:
        S[:,0:mfsc.shape[1]] = mfsc[:,0:256]
    #S_delta = librosa.feature.delta(S)
    #S_delta2 = librosa.feature.delta(S, order=2)
    #print y.shape
    #print S
    S_db = librosa.power_to_db(S,ref=np.max)
    
    
    fig_name= file.split("\t")[1].strip("\n") +str(linecount)+".png"
    #matplotlib.image.imsave(fig_name,S_db)
    #fig_name= plt.figure(figsize=(10, 4))
    #librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time')
    #plt.colorbar(format='%+2.0f dB')
    #plt.title('Mel spectrogram')
    #fig_name.savefig("fig"+str(linecount)+'.png')
    #print S_db.shape
    
    '''
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_db,y_axis='mel', fmax=8000,x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    '''
    #print S_db.shape

    print label_dict[file.split("\t")[1].strip("\n")]
    
    if linecount in ind2:
        matplotlib.image.imsave(os.path.join("./train",fig_name ),S_db)
 
    else:
        matplotlib.image.imsave(os.path.join("./validation",fig_name ),S_db)                                   
                                        
                    
        
    linecount = linecount + 1

files.close()



'''

size = []
i=0
for file in files:
    file =file.strip("\n")+".wav"
    y,sr = librosa.load(os.path.join("../Complete", file))
    
    size.append(librosa.feature.melspectrogram(y=y, sr=sr, n_mels = 128, fmax =8000).shape[1])
    i=i+1
print size
'''
# Out:
# ['Ses01F_impro01_F000', 'Neutral\n']
# (128, 84)
# 0
# ['Ses01F_impro01_F001', 'Neutral\n']
# (128, 60)
# 0
# ['Ses01F_impro01_F002', 'Neutral\n']
# (128, 135)
# 0
# ['Ses01F_impro01_F005', 'Neutral\n']
# (128, 174)
# 0
# ['Ses01F_impro01_F012', 'Anger\n']
# (128, 119)
# 3
# ['Ses01F_impro01_F014', 'Neutral\n']
# (128, 219)
# 0
# ['Ses01F_impro01_M013', 'Anger\n']
# (128, 260)
# 3
# ['Ses01F_impro02_F000', 'Sadness\n']
# (128, 402)
# 2
# ['Ses01F_impro02_F001', 'Sadness\n']
# (128, 127)
# 2
# ['Ses01F_impro02_F002', 'Sadness\n']
# (128, 247)
# 2
# ['Ses01F_impro02_F003', 'Neutral\n']
# (128, 244)
# 0
# ['Ses01F_impro02_F004', 'Sadness\n']
# (128, 249)
# 2
# ['Ses01F_impro02_F005', 'Sadness\n']
# (128, 111)
# 2
# ['Ses01F_impro02_F006', 'Neutral\n']
# (128, 182)
# 0
# ['Ses01F_impro02_F010', 'Sadness\n']
# (128, 184)
# 2
# ['Ses01F_impro02_F012', 'Sadness\n']
# (128, 131)
# 2
# ['Ses01F_impro02_F013', 'Sadness\n']
# (128, 264)
# 2
# ['Ses01F_impro02_F014', 'Sadness\n']
# (128, 319)
# ...
